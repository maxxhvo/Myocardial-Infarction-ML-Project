# %% [markdown]
# ### Author: Max Vo

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
current_dir = Path.cwd()

# %% [markdown]
# ## Data Loading and Dummy Variable Creation for Categorical Features

# %%
# ln -s ../Finalized_Feature_Sets/model_data_simple.parquet model_data_simple.parquet

# ln -s ../Finalized_Feature_Sets/non-imputed_data.parquet non-imputed_data.parquet

# %%
model_data_simple = pd.read_parquet(
    "model_data_simple.parquet",
    engine="pyarrow"
    )

# %%
# confirm train_dummy split proportion

model_data_simple["train_dummy"].value_counts(normalize=True)
# Out:
# train_dummy
# 1    0.749412
# 0    0.250588
# Name: proportion, dtype: float64

# %%
model_data_simple.shape
# Out:
# (1700, 31)

# %%
feature_cols = model_data_simple.columns.drop(["ZSN", "train_dummy"])

x_train = model_data_simple.loc[model_data_simple["train_dummy"] == 1, feature_cols]
y_train = model_data_simple.loc[model_data_simple["train_dummy"] == 1, "ZSN"]

x_test = model_data_simple.loc[model_data_simple["train_dummy"] == 0, feature_cols]
y_test = model_data_simple.loc[model_data_simple["train_dummy"] == 0, "ZSN"]

# %%
# one hot encode categorical features for tree-based models (no need to drop first category since trees are not affected by multicollinearity)
x_train = pd.get_dummies(x_train, drop_first=False)
x_test = pd.get_dummies(x_test, drop_first=False)

x_train, x_test = x_train.align(
    x_test,
    join="left",
    axis=1,
    fill_value=0
)
print(set(x_train.columns) - set(x_test.columns)) # should be empty set
# Out:
# set()

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_train.columns.tolist())
# Out:
# (1274, 46) (1274,)
# (426, 46) (426,)
# ['AGE', 'SEX', 'INF_ANAM', 'IBS_POST', 'GB', 'endocr_01', 'S_AD_ORIT', 'D_AD_ORIT', 'O_L_POST', 'MP_TP_POST', 'NA_BLOOD', 'K_BLOOD', 'L_BLOOD', 'ant_im', 'lat_im', 'inf_im', 'post_im', 'ritm_ecg_p_01', 'any_pulmonary_disease', 'any_arrhythmia', 'any_conduction_block', 'ROE_log', 'ALT_BLOOD_log', 'AST_BLOOD_log', 'ZSN_A_recode_mild', 'ZSN_A_recode_missing', 'ZSN_A_recode_moderate_severe', 'ZSN_A_recode_none', 'time_bin_early', 'time_bin_intermediate', 'time_bin_late', 'time_bin_missing', 'angina_timing_intermediate', 'angina_timing_missing', 'angina_timing_never', 'angina_timing_recent', 'angina_timing_remote', 'angina_severity_missing', 'angina_severity_moderate', 'angina_severity_none', 'angina_severity_other', 'htn_duration_long', 'htn_duration_medium', 'htn_duration_missing', 'htn_duration_none', 'htn_duration_short']

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# ### Important Hyperparameters to tune:
#
# * max_depth: The maximum depth of the tree
# * min_samples_leaf: The minimum number of samples required to be at a leaf node
# * max_features: The number of features to consider when looking for the best split
#
# ### Additional Stability Parameters:
#
# * n_estimators: The number of trees in the forest
# * class_weight: due to class imbalance ~ may set to "balanced"

# %% [markdown]
# ### Exploratory Grid for Hyperparameter Tuning

# %%
# Exploratory Grid for Hyperparameter Tuning

param_grid = {
    "n_estimators": [200, 300, 500],
    "max_depth": [5, 8, 12, None],
    "min_samples_leaf": [1, 5, 10],
    "max_features": ["sqrt", "log2", 0.5],
    "class_weight": [None, "balanced"]
}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import make_scorer, average_precision_score

rf = RandomForestClassifier(
    random_state=321,
    n_jobs = 8
)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=321
)

rf_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_grid,
    n_iter=50,
    scoring="average_precision",   # PR AUC
    cv=cv,
    n_jobs=8,
    random_state=321,
    verbose=1,
    return_train_score=True
)

# %% [markdown]
# ## Exploratory Cross Validation for Hyperparameter Tuning (using PR AUC as scoring metric)

# %%
rf_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=321, shuffle=True),
#                    estimator=RandomForestClassifier(n_jobs=8, random_state=321),
#                    n_iter=50, n_jobs=8,
#                    param_distributions={'class_weight': [None, 'balanced'],
#                                         'max_depth': [5, 8, 12, None],
#                                         'max_features': ['sqrt', 'log2', 0.5],
#                                         'min_samples_leaf': [1, 5, 10],
#                                         'n_estimators': [200, 300, 500]},
#                    random_state=321, return_train_score=True,
#                    scoring='average_precision', verbose=1)

# %%
print("Best PR AUC:", rf_search.best_score_)
print("Best params:", rf_search.best_params_)
# Out:
# Best PR AUC: 0.4874882299852
# Best params: {'n_estimators': 200, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': None}

# %%
rf_results = pd.DataFrame(rf_search.cv_results_)

rf_results[["mean_train_score", "mean_test_score"]].head()
# Out:
#    mean_train_score  mean_test_score
# 0          0.949462         0.465592
# 1          0.796167         0.478326
# 2          0.801175         0.465549
# 3          0.830937         0.481001
# 4          0.927870         0.469417

# %%
rf_results = pd.DataFrame(rf_search.cv_results_)

cols = [
    "mean_test_score", "std_test_score", "mean_train_score",
    "param_n_estimators", "param_max_depth",
    "param_min_samples_leaf", "param_max_features",
    "param_class_weight"
]

rf_results[cols].sort_values("mean_test_score", ascending=False).head(15)
# Out:
#     mean_test_score  std_test_score  mean_train_score  param_n_estimators  \
# 12         0.487488        0.033060          0.694350                 200
# 43         0.482809        0.041896          0.776854                 500
# 13         0.482657        0.037739          0.699540                 500
# 10         0.481703        0.048382          0.728735                 200
# 3          0.481001        0.038909          0.830937                 300
# 36         0.479449        0.052169          0.951932                 200
# 1          0.478326        0.040591          0.796167                 500
# 25         0.475956        0.048646          0.858429                 200
# 19         0.475881        0.050929          0.716116                 300
# 49         0.475532        0.045906          0.940490                 200
# 14         0.475053        0.039952          0.862605                 300
# 20         0.474942        0.055115          0.890856                 200
# ...

# %% [markdown]
# __mean_train_score:__ Average PR AUC on the TRAINING folds (in-sample performance)
# __mean_test_score:__ Average PR AUC on the TEST folds (out-of-sample performance)
#
# ### From the exploratory hyperparameter tuning grid we see:
#
# The following Pattern Repeats across the top 5 performing models:
#
# * max_depth = 5
#     * higher depth with other parameters does not seem to improve performance (overfitting)
#     * max_depth should be shallow (≈ 4–6)
# * min_samples_leaf = 10
#     * strong regularization does seem to improve performance (less overfitting)
#     * perhaps fit with ~ min_samples_leaf ∈ [5, 10, 20]
# * max_features = sqrt
#     * reasonable default for our task ~ 0.5 also seems to perform decently
#
# * n_estimators does not seem to have a strong impact on performance; the top performing models have n_estimators = 200, 300, and 500. Fixing n_estimators = 300 is sufficient for our task.
#
# * Class Weight seems to have little impact on performance, likely because the Random Forest is already robust to class imbalance
#
# The Data Overally seems to prefer Smooth and Shallower Trees with Stronger Regularization (lower max_depth, higher min_samples_leaf) to prevent overfitting and improve generalization performance. This is likely due to the relatively small dataset size and high feature dimensionality, which can lead to overfitting if the trees are too deep or not sufficiently regularized.

# %% [markdown]
# ## Revised Hyperparameter Grid for Tuning

# %%
param_grid_refined = {
    "max_depth": [3, 4, 5, 6, 7],
    "min_samples_leaf": [5, 8, 10, 12, 15, 18], # more granular exploration around best value of 10
    "max_features": ["sqrt", 0.5],
    "class_weight": [None, "balanced"],
    "n_estimators": [300]  # fixed
}

# %%
from sklearn.model_selection import GridSearchCV

rf_search_refined = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_refined,
    scoring="average_precision",
    cv=cv,
    n_jobs=8,
    verbose=1,
    return_train_score=True
)

# %%
import warnings

# issues with sklearn's parallel processing and joblib backend causing spurious warnings about "delayed" objects not being picklable
warnings.filterwarnings(
    "ignore",
    message=".*sklearn.utils.parallel.delayed.*"
)

# %%
rf_search_refined.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=321, shuffle=True),
#              estimator=RandomForestClassifier(n_jobs=8, random_state=321),
#              n_jobs=8,
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_depth': [3, 4, 5, 6, 7],
#                          'max_features': ['sqrt', 0.5],
#                          'min_samples_leaf': [5, 8, 10, 12, 15, 18],
#                          'n_estimators': [300]},
#              return_train_score=True, scoring='average_precision', verbose=1)

# %%
print("Best PR AUC:", rf_search_refined.best_score_)
print("Best params:", rf_search_refined.best_params_)
# Out:
# Best PR AUC: 0.49024163368706064
# Best params: {'class_weight': None, 'max_depth': 3, 'max_features': 0.5, 'min_samples_leaf': 18, 'n_estimators': 300}

# %%
rf_results = pd.DataFrame(rf_search_refined.cv_results_)

cols = [
    "mean_test_score", "std_test_score", "mean_train_score",
    "param_n_estimators", "param_max_depth",
    "param_min_samples_leaf", "param_max_features",
    "param_class_weight"
]

rf_results[cols].sort_values("mean_test_score", ascending=False).head(15)
# Out:
#     mean_test_score  std_test_score  mean_train_score  param_n_estimators  \
# 11         0.490242        0.045652          0.604575                 300
# 22         0.489196        0.045593          0.661480                 300
# 10         0.488301        0.049225          0.612886                 300
# 9          0.488288        0.052535          0.619279                 300
# 26         0.487796        0.036594          0.698125                 300
# 21         0.487564        0.048206          0.672382                 300
# 7          0.487280        0.054682          0.626301                 300
# 47         0.487118        0.046606          0.718399                 300
# 35         0.486242        0.050083          0.685798                 300
# 23         0.485985        0.044371          0.649234                 300
# 38         0.485571        0.035691          0.734467                 300
# 8          0.485472        0.051832          0.622954                 300
# ...

# %% [markdown]
# The cross-validation results indicate that the Random Forest performs best under strong regularization, with shallow trees (max_depth ≈ 3–4) and larger leaf sizes (min_samples_leaf ≈ 12–18) achieving the highest PR AUC (~0.49). Increasing model complexity leads to higher training performance but does not improve validation performance, indicating overfitting. Using max_features = 0.5 further improves generalization, suggesting that additional feature randomness is beneficial. The class_weight parameter does not meaningfully impact performance, as top models consistently use class_weight=None with slightly better PR AUC. This likely reflects the model’s inherent ability to handle moderate class imbalance and the use of PR AUC, which emphasizes ranking over class boundary shifts. Overall, these results suggest that the dataset favors simple, smooth decision boundaries, and that additional model complexity is unlikely to yield meaningful performance gains.

# %% [markdown]
# ## Additional Visualization of Hyperparameter Tuning Results
#
# * 2nd plot focuses on the 2 hyperparameters that have the most impact on performance (max_depth & min_samples_leaf) and shows how PR AUC(mean_test_score) varies with these parameters while fixing n_estimators = 300 and class_weight = None.

# %%
rf_results = pd.DataFrame(rf_search_refined.cv_results_)

# get top 10 configs by mean CV PR AUC
top = rf_results.sort_values("mean_test_score", ascending=False).head(10).copy()
top["model_rank"] = range(1, len(top) + 1)

fold_cols = [c for c in rf_results.columns if c.startswith("split") and c.endswith("_test_score")]

top_long = top.melt(
    id_vars=["model_rank", "mean_test_score"],
    value_vars=fold_cols,
    var_name="fold",
    value_name="pr_auc"
)

plt.figure(figsize=(10, 6))
sns.boxplot(data=top_long, x="model_rank", y="pr_auc")
sns.stripplot(data=top_long, x="model_rank", y="pr_auc", color="black", alpha=0.6)

plt.xlabel("Model rank by mean CV PR AUC")
plt.ylabel("Fold PR AUC")
plt.title("Cross-validation fold PR AUC for top RF configurations")
plt.tight_layout()
plt.show() # points are jittered for visibility

# %%
sns.lineplot(
    data=rf_results,
    x="param_max_depth",
    y="mean_test_score",
    hue="param_min_samples_leaf",
    marker="o"
)

plt.ylabel("Mean CV PR AUC")
plt.xlabel("max_depth")
plt.title("RF CV Performance by max_depth and min_samples_leaf")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Metrics on The Training Data Itself for the Best Model

# %%
best_rf = rf_search_refined.best_estimator_
y_train_pred = best_rf.predict(x_train)

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

target_names = ['No Chronic Heart Failure', 'Chronic Heart Failure']
print(classification_report(y_train, y_train_pred, target_names=target_names))
# Out:
#                           precision    recall  f1-score   support
#
# No Chronic Heart Failure       0.82      0.99      0.89       988
#    Chronic Heart Failure       0.87      0.23      0.36       286
#
#                 accuracy                           0.82      1274
#                macro avg       0.84      0.61      0.63      1274
#             weighted avg       0.83      0.82      0.77      1274

# %% [markdown]
# * The model shows very high recall for the majority class (0.99), indicating it almost always correctly identifies patients without CHF.
# * For the CHF class, precision is high (0.87) but recall is low (0.23), meaning predicted CHF cases are usually correct, but many true CHF cases are missed
#     * The model is therefore conservative in predicting the positive class, favoring fewer false positives at the cost of more false negatives.
#     * perhaps a lowered threshold for model prediction could improve recall (y_proba >= 0.3 instead of 0.5)
#
# * The gap between classes reflects the class imbalance and the model’s regularization, which biases predictions toward the majority class.

# %%
cnf_matrix = metrics.confusion_matrix(y_train, y_train_pred)
cnf_matrix = pd.DataFrame(cnf_matrix)
cnf_matrix.columns = ['predicted_no_CHF', 'predicted_CHF']
cnf_matrix.index = ['true_no_CHF', 'true_CHF']
cnf_matrix
# Out:
#              predicted_no_CHF  predicted_CHF
# true_no_CHF               978             10
# true_CHF                  221             65

# %%
# dir(best_rf)

best_rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': 0.5,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 18,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 300,
#  'n_jobs': 8,
#  'oob_score': False,
#  'random_state': 321,
#  'verbose': 0,
#  'warm_start': False}

# %%
feature_names = x_train.columns
# Compute the variable importance
importances = best_rf.feature_importances_
dict_importance = {k:np.round(v,3) for (k,v) in zip(feature_names, importances)}
# Print the variable importance
print(dict_importance)
# Out:
# {'AGE': np.float64(0.069), 'SEX': np.float64(0.003), 'INF_ANAM': np.float64(0.002), 'IBS_POST': np.float64(0.002), 'GB': np.float64(0.004), 'endocr_01': np.float64(0.029), 'S_AD_ORIT': np.float64(0.019), 'D_AD_ORIT': np.float64(0.011), 'O_L_POST': np.float64(0.001), 'MP_TP_POST': np.float64(0.01), 'NA_BLOOD': np.float64(0.007), 'K_BLOOD': np.float64(0.01), 'L_BLOOD': np.float64(0.019), 'ant_im': np.float64(0.002), 'lat_im': np.float64(0.001), 'inf_im': np.float64(0.001), 'post_im': np.float64(0.0), 'ritm_ecg_p_01': np.float64(0.014), 'any_pulmonary_disease': np.float64(0.029), 'any_arrhythmia': np.float64(0.002), 'any_conduction_block': np.float64(0.001), 'ROE_log': np.float64(0.012), 'ALT_BLOOD_log': np.float64(0.015), 'AST_BLOOD_log': np.float64(0.016), 'ZSN_A_recode_mild': np.float64(0.538), 'ZSN_A_recode_missing': np.float64(0.022), 'ZSN_A_recode_moderate_severe': np.float64(0.01), 'ZSN_A_recode_none': np.float64(0.131), 'time_bin_early': np.float64(0.001), 'time_bin_intermediate
# ...

# %%
feature_imp = pd.Series(best_rf.feature_importances_, index=x_train.columns)

# subset to top 10 features for better visualization
top10 = feature_imp.sort_values(ascending=False).head(10)

top10.sort_values().plot.barh(color='green')  # sort for horizontal plot
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Top 10 Feature Importance");

# %% [markdown]
# ## Evaluating Model Performance on Test Set

# %%
# Predict Y values of trauining data
y_test_pred = best_rf.predict(x_test)
target_names = [' no CHF', 'with CHF']

print('\n------------\n'+
      'Classification report on test data' +
      '\n------------\n')
print(classification_report(y_test, y_test_pred, target_names=target_names))

#Confusion matrix
cnf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cnf_matrix = pd.DataFrame(cnf_matrix)
cnf_matrix.columns = ['predicted_no_CHF', 'predicted_with_CHF']
cnf_matrix.index = ['true_no_CHF', 'true_with_CHF']

print('\n------------\n'+
      'Confusion matrix on test data' +
      '\n------------\n')

print(cnf_matrix)
# Out:
# ------------
# Classification report on test data
# ------------
#
#               precision    recall  f1-score   support
#
#       no CHF       0.79      0.99      0.88       318
#     with CHF       0.89      0.23      0.37       108
#
#     accuracy                           0.80       426
#    macro avg       0.84      0.61      0.62       426
# weighted avg       0.82      0.80      0.75       426
#
#
# ------------
# Confusion matrix on test data
# ------------
#
#                predicted_no_CHF  predicted_with_CHF
# true_no_CHF                 315                   3
# true_with_CHF                83                  25

# %% [markdown]
# From the results above, using the default probability threshold of 0.5 is inappropriate in imbalanced clinical prediction tasks because it implicitly assumes equal costs for false positives and false negatives. In this setting, the model achieves high precision but very low recall, meaning many true CHF cases are missed (high false negatives), which is clinically undesirable. Since failing to identify at-risk patients can have serious consequences, the threshold should be lowered to achieve a target recall (e.g., 0.8), ensuring most true cases are captured. This adjustment intentionally increases false positives, but that tradeoff is acceptable in a screening context where additional follow-up is relatively low risk compared to missing a critical condition.
#
# Mathematically, an increased desired recall corresponds to a lower threshold on the predicted probabilities, which allows more positive predictions and thus captures more true positives at the cost of also including more false positives. The optimal threshold can be determined by analyzing the precision-recall curve or using metrics like the F1 score to balance precision and recall according to clinical priorities.

# %%
# threshold selection using ROC curve analysis, on the training set to avoid data leakage and overfitting to the test set
y_train_prob = best_rf.predict_proba(x_train)[:, 1]

fpr, tpr, roc_thresholds = roc_curve(y_train, y_train_prob)

# %%
desired_recall = 0.80

valid_idx = np.where(tpr >= desired_recall)[0]
best_idx = valid_idx[np.argmin(fpr[valid_idx])]

chosen_threshold = roc_thresholds[best_idx]

print("Threshold:", chosen_threshold)
print("Recall:", tpr[best_idx])
print("FPR:", fpr[best_idx])
# Out:
# Threshold: 0.1862085144225307
# Recall: 0.8041958041958042
# FPR: 0.47874493927125505

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_test_prob = best_rf.predict_proba(x_test)[:, 1]
y_pred_new = (y_test_prob >= chosen_threshold).astype(int)
target_names = [' no CHF', 'with CHF']

print('\n------------\n'+
      'Classification report on test data with adjusted threshold' +
      '\n------------\n')
print(classification_report(y_test, y_pred_new, target_names=target_names))

#Confusion matrix
cnf_matrix = metrics.confusion_matrix(y_test, y_pred_new)
cnf_matrix = pd.DataFrame(cnf_matrix)
cnf_matrix.columns = ['predicted_no_CHF', 'predicted_with_CHF']
cnf_matrix.index = ['true_no_CHF', 'true_with_CHF']

print('\n------------\n'+
      'Confusion matrix on test data with adjusted threshold' +
      '\n------------\n')

print(cnf_matrix)
# Out:
# ------------
# Classification report on test data with adjusted threshold
# ------------
#
#               precision    recall  f1-score   support
#
#       no CHF       0.86      0.55      0.67       318
#     with CHF       0.36      0.73      0.48       108
#
#     accuracy                           0.60       426
#    macro avg       0.61      0.64      0.57       426
# weighted avg       0.73      0.60      0.62       426
#
#
# ------------
# Confusion matrix on test data with adjusted threshold
# ------------
#
#                predicted_no_CHF  predicted_with_CHF
# true_no_CHF                 175                 143
# true_with_CHF                29                  79

# %% [markdown]
# Lowering the classification threshold increased recall for CHF cases from 0.23 to 0.73, reducing false negatives from 83 to 29. This improvement was accompanied by an increase in false positives and a decrease in precision (0.36), illustrating the inherent tradeoff between sensitivity and specificity. Importantly, selecting the threshold based on training data resulted in a more moderate and generalizable balance compared to the more aggressive threshold derived from test data, while still prioritizing the reduction of missed CHF cases in a clinically relevant manner.

# %% [markdown]
# ## ROC Curve (Receiver Operating Curve), AUC (Area Under the Curve)
#
# * Comparison of ROC curves for the original threshold (0.5) and the new threshold (~0.186) shows that the new threshold achieves a much higher TPR (recall) at the cost of a higher FPR, which is consistent with our earlier analysis of the precision-recall tradeoff.
# * Comparison of training and test ROC curves

# %%
y_train_prob = best_rf.predict_proba(x_train)[:, 1]
y_train_pred = (y_train_prob >= chosen_threshold).astype(int)


y_test_prob = best_rf.predict_proba(x_test)[:, 1]
y_test_pred = (y_test_prob >= chosen_threshold).astype(int)

# %%
from sklearn.metrics import (
    roc_curve, roc_auc_score,
    precision_recall_curve, average_precision_score
)

dict_eval = {}

for dset in ["train", "test"]:

    if dset == "train":
        x, y = x_train, y_train
    else:
        x, y = x_test, y_test

    # predict probabilities
    y_prob = best_rf.predict_proba(x)[:, 1]

    # ROC curve with thresholds
    fpr, tpr, roc_thresholds = roc_curve(y, y_prob)
    roc_auc = roc_auc_score(y, y_prob)

    # precision-recall curve
    precision, recall, pr_thresholds = precision_recall_curve(y, y_prob)
    pr_auc = average_precision_score(y, y_prob)

    dict_eval[dset] = {
        "fpr": fpr,
        "tpr": tpr,
        "roc_thresholds": roc_thresholds,
        "roc_auc": roc_auc,
        "prec": precision,
        "recall": recall,
        "pr_thresholds": pr_thresholds,
        "pr_auc": pr_auc
    }

# %%
# Plot ROC curves
plt.plot(dict_eval["train"]["fpr"], dict_eval["train"]["tpr"],
         marker=".", label="Train set")

plt.plot(dict_eval["test"]["fpr"], dict_eval["test"]["tpr"],
         marker=".", label="Test set")

# y=x baseline
plt.plot([0, 1], [0, 1], linestyle="--", color="grey")

anno_list = {}

for dset in ["train", "test"]:

    fpr = dict_eval[dset]["fpr"]
    tpr = dict_eval[dset]["tpr"]
    roc_thresholds = dict_eval[dset]["roc_thresholds"]

    # closest ROC point to chosen threshold
    idx = np.argmin(np.abs(roc_thresholds - chosen_threshold))

    fpr_point = fpr[idx]
    tpr_point = tpr[idx]

    # vertical dotted line at FPR for this threshold
    plt.plot(
        [fpr_point, fpr_point],
        [0, tpr_point],
        linestyle=":",
        color="grey"
    )

    # horizontal dotted line to show recall/TPR
    plt.plot(
        [0, fpr_point],
        [tpr_point, tpr_point],
        linestyle=":",
        color="grey"
    )

    # threshold point
    plt.plot(
        [fpr_point],
        [tpr_point],
        marker="o",
        linestyle="None",
        label=f"{dset} threshold point"
    )

    anno_str = (
    f"{dset}: FPR={fpr_point:.2f}, Recall={tpr_point:.2f}\n"
    f"prob threshold={chosen_threshold:.2f}"
    )

    if dset == "train":
        plt.text(
            fpr_point + 0.02,
            tpr_point + 0.02,
            anno_str,
            fontsize=9,
            bbox=dict(facecolor="white", alpha=0.3, edgecolor="none")
        )
    else:
        plt.text(
            fpr_point - 0.15,
            tpr_point - 0.08,
            anno_str,
            fontsize=9,
            bbox=dict(facecolor="white", alpha=0.3, edgecolor="none")

        )

    anno_list[dset] = f"AUC({dset}): {dict_eval[dset]['roc_auc']:.2f}"



# AUC annotation
auc_str = anno_list["train"] + "\n" + anno_list["test"]
plt.text(0.6, 0.3, auc_str)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Random Forest Model (Train vs Test, Adjusted Threshold)")
plt.legend()
plt.show()

# %%
# Plot PR curves
plt.plot(
    dict_eval["train"]["recall"],
    dict_eval["train"]["prec"],
    marker=".",
    label="Train set"
)

plt.plot(
    dict_eval["test"]["recall"],
    dict_eval["test"]["prec"],
    marker=".",
    label="Test set"
)

# y=x line.
plt.plot([0,1], [1,0], linestyle='--', color='grey' )

anno_list = {}

for dset in ["train", "test"]:

    recall = dict_eval[dset]["recall"]
    precision = dict_eval[dset]["prec"]
    pr_thresholds = dict_eval[dset]["pr_thresholds"]

    # match chosen threshold to PR curve
    idx = np.argmin(np.abs(pr_thresholds - chosen_threshold))

    recall_point = recall[idx]
    precision_point = precision[idx]

    # vertical line (recall)
    plt.plot(
        [recall_point, recall_point],
        [0, precision_point],
        linestyle=":",
        color="grey"
    )

    # horizontal line (precision)
    plt.plot(
        [0, recall_point],
        [precision_point, precision_point],
        linestyle=":",
        color="grey"
    )

    # threshold point
    plt.plot(
        [recall_point],
        [precision_point],
        marker="o",
        linestyle="None",
        label=f"{dset} threshold point"
    )

    anno_str = (
        f"{dset}: Recall={recall_point:.2f}, Precision={precision_point:.2f}\n"
        f"prob threshold={chosen_threshold:.2f}"
    )

    # offset labels to avoid overlap
    if dset == "train":
        plt.text(
            recall_point - 0.30,
            precision_point + 0.05,
            anno_str,
            fontsize=9,
            bbox=dict(facecolor="white", alpha=0.3, edgecolor="none")
        )
    else:
        plt.text(
            recall_point - 0.35,
            precision_point - 0.12,
            anno_str,
            fontsize=9,
            bbox=dict(facecolor="white", alpha=0.3, edgecolor="none")
        )

    anno_list[dset] = f"PR AUC({dset}): {dict_eval[dset]['pr_auc']:.2f}"

# AUC annotation
auc_str = anno_list["train"] + "\n" + anno_list["test"]
plt.text(
    0.05, 0.15,
    auc_str,
    fontsize=10,
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="none")
)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve for Random Forest Model (Train vs Test, Adjusted Threshold)")
plt.legend()
plt.show()

# %% [markdown]
# The ROC and Precision–Recall plots together indicate that the Random Forest model has moderate ability to distinguish between patients with and without CHF, with performance that generalizes reasonably well from training to test data. The ROC AUC values (≈0.77 for training and ≈0.73 for testing) suggest that the model can rank patients by risk better than chance, although not exceptionally well. In contrast, the Precision–Recall AUC values (≈0.60 and ≈0.59) are lower, which is expected given the class imbalance in the dataset and reflects the greater difficulty of achieving high precision when the positive class is relatively rare. This difference between ROC and PR performance highlights that while the model is reasonably good at ranking risk, its practical predictive utility is more limited when evaluated in terms of precision.
# The highlighted points on both plots correspond to the model’s performance at the selected probability threshold of approximately 0.19. This threshold was not chosen arbitrarily; rather, it was determined by targeting a desired recall level of about 0.8 on the training data, reflecting a clinical preference to capture as many true CHF cases as possible. On the ROC curve, this operating point appears around a true positive rate (recall) of roughly 0.74–0.80 and a false positive rate of approximately 0.45–0.48. This means that while the model successfully identifies a large proportion of true CHF cases, it also incorrectly flags a substantial number of non-CHF patients as positive.
# The Precision–Recall curve provides a complementary view of this same threshold choice. At the selected threshold, recall remains high (≈0.74–0.80), but precision drops to approximately 0.33–0.36. In practical terms, this means that only about one-third of the patients predicted to have CHF actually do, indicating a significant number of false positives. This behavior is consistent with lowering the classification threshold: more patients are labeled as positive, which increases sensitivity but decreases precision.
# Importantly, this tradeoff is intentional and aligns with the clinical objective of the model. In many medical screening contexts, including CHF risk prediction, failing to identify a true case (false negative) can have more serious consequences than incorrectly flagging a patient (false positive). Therefore, selecting a lower threshold to prioritize recall is justified, even though it results in reduced precision. The plotted threshold points make this tradeoff explicit by showing the exact operating position of the model on both curves, emphasizing that model evaluation depends not only on overall performance metrics but also on how the decision threshold is chosen to reflect real-world priorities.
